# %%
pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.3.1-py3-none-any.whl (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.4/840.4 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (1.25.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (24.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.2.1+cu121)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.10.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 63.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 94.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.1 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 27.5 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 10.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->torchmetrics)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->torchmetrics) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->torchmetrics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->torchmetrics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchmetrics
# Successfully installed lightning-utilities-0.10.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 torchmetrics-1.3.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import gc
import os
import cv2
import math
import base64
import random
import numpy as np
from PIL import Image
from tqdm import tqdm
from datetime import datetime
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.cuda import amp
import torch.nn.functional as F
from torch.optim import Adam, AdamW
from torch.utils.data import Dataset, DataLoader

import torchvision
import torchvision.transforms as TF
import torchvision.datasets as datasets
from torchvision.utils import make_grid

from torchmetrics import MeanMetric

from IPython.display import display, HTML, clear_output

import torch
from torch.cuda import memory_allocated
from torch.cuda import empty_cache
from torch.cuda import memory_cached
from torch.cuda import reset_max_memory_allocated

# %% [markdown]
# # UNet

# %%
class SinusoidalPositionEmbeddings(nn.Module):
    def __init__(self, total_time_steps=1000, time_emb_dims=128, time_emb_dims_exp=512):
        super().__init__()

        half_dim = time_emb_dims // 2

        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, dtype=torch.float32) * -emb)

        ts = torch.arange(total_time_steps, dtype=torch.float32)

        emb = torch.unsqueeze(ts, dim=-1) * torch.unsqueeze(emb, dim=0)
        emb = torch.cat((emb.sin(), emb.cos()), dim=-1)

        self.time_blocks = nn.Sequential(
            nn.Embedding.from_pretrained(emb),
            nn.Linear(in_features=time_emb_dims, out_features=time_emb_dims_exp),
            nn.SiLU(),
            nn.Linear(in_features=time_emb_dims_exp, out_features=time_emb_dims_exp),
        )

    def forward(self, time):
        return self.time_blocks(time)


class AttentionBlock(nn.Module):
    def __init__(self, channels=64):
        super().__init__()
        self.channels = channels

        self.group_norm = nn.GroupNorm(num_groups=8, num_channels=channels)
        self.mhsa = nn.MultiheadAttention(embed_dim=self.channels, num_heads=4, batch_first=True)

    def forward(self, x):
        B, _, H, W = x.shape
        h = self.group_norm(x)
        h = h.reshape(B, self.channels, H * W).swapaxes(1, 2)  # [B, C, H, W] --> [B, C, H * W] --> [B, H*W, C]
        h, _ = self.mhsa(h, h, h)  # [B, H*W, C]
        h = h.swapaxes(2, 1).view(B, self.channels, H, W)  # [B, C, H*W] --> [B, C, H, W]
        return x + h


class ResnetBlock(nn.Module):
    def __init__(self, *, in_channels, out_channels, dropout_rate=0.1, time_emb_dims=512, apply_attention=False):
        super().__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels

        self.act_fn = nn.SiLU()
        # Group 1
        self.normlize_1 = nn.GroupNorm(num_groups=8, num_channels=self.in_channels)
        self.conv_1 = nn.Conv2d(in_channels=self.in_channels, out_channels=self.out_channels, kernel_size=3, stride=1, padding="same")

        # Group 2 time embedding
        self.dense_1 = nn.Linear(in_features=time_emb_dims, out_features=self.out_channels)

        # Group 3
        self.normlize_2 = nn.GroupNorm(num_groups=8, num_channels=self.out_channels)
        self.dropout = nn.Dropout2d(p=dropout_rate)
        self.conv_2 = nn.Conv2d(in_channels=self.out_channels, out_channels=self.out_channels, kernel_size=3, stride=1, padding="same")

        if self.in_channels != self.out_channels:
            self.match_input = nn.Conv2d(in_channels=self.in_channels, out_channels=self.out_channels, kernel_size=1, stride=1)
        else:
            self.match_input = nn.Identity()

        if apply_attention:
            self.attention = AttentionBlock(channels=self.out_channels)
        else:
            self.attention = nn.Identity()

    def forward(self, x, t):
        # group 1
        h = self.act_fn(self.normlize_1(x))
        h = self.conv_1(h)

        # group 2
        # add in timestep embedding
        h += self.dense_1(self.act_fn(t))[:, :, None, None]

        # group 3
        h = self.act_fn(self.normlize_2(h))
        h = self.dropout(h)
        h = self.conv_2(h)

        # Residual and attention
        h = h + self.match_input(x)
        h = self.attention(h)

        return h


class DownSample(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.downsample = nn.Conv2d(in_channels=channels, out_channels=channels, kernel_size=3, stride=2, padding=1)

    def forward(self, x, *args):
        return self.downsample(x)


class UpSample(nn.Module):
    def __init__(self, in_channels):
        super().__init__()

        self.upsample = nn.Sequential(
            nn.Upsample(scale_factor=2, mode="nearest"),
            nn.Conv2d(in_channels=in_channels, out_channels=in_channels, kernel_size=3, stride=1, padding=1),
        )

    def forward(self, x, *args):
        return self.upsample(x)


class UNet(nn.Module):
    def __init__(
        self,
        input_channels=3,
        output_channels=3,
        num_res_blocks=2,
        base_channels=128,
        base_channels_multiples=(1, 2, 4, 8),
        apply_attention=(False, False, True, False),
        dropout_rate=0.1,
        time_multiple=4,
    ):
        super().__init__()

        time_emb_dims_exp = base_channels * time_multiple
        self.time_embeddings = SinusoidalPositionEmbeddings(time_emb_dims=base_channels, time_emb_dims_exp=time_emb_dims_exp)

        self.first = nn.Conv2d(in_channels=input_channels, out_channels=base_channels, kernel_size=3, stride=1, padding="same")

        num_resolutions = len(base_channels_multiples)

        # Encoder part of the UNet. Dimension reduction.
        self.encoder_blocks = nn.ModuleList()
        curr_channels = [base_channels]
        in_channels = base_channels

        for level in range(num_resolutions):
            out_channels = base_channels * base_channels_multiples[level]

            for _ in range(num_res_blocks):

                block = ResnetBlock(
                    in_channels=in_channels,
                    out_channels=out_channels,
                    dropout_rate=dropout_rate,
                    time_emb_dims=time_emb_dims_exp,
                    apply_attention=apply_attention[level],
                )
                self.encoder_blocks.append(block)

                in_channels = out_channels
                curr_channels.append(in_channels)

            if level != (num_resolutions - 1):
                self.encoder_blocks.append(DownSample(channels=in_channels))
                curr_channels.append(in_channels)

        # Bottleneck in between
        self.bottleneck_blocks = nn.ModuleList(
            (
                ResnetBlock(
                    in_channels=in_channels,
                    out_channels=in_channels,
                    dropout_rate=dropout_rate,
                    time_emb_dims=time_emb_dims_exp,
                    apply_attention=True,
                ),
                ResnetBlock(
                    in_channels=in_channels,
                    out_channels=in_channels,
                    dropout_rate=dropout_rate,
                    time_emb_dims=time_emb_dims_exp,
                    apply_attention=False,
                ),
            )
        )

        # Decoder part of the UNet. Dimension restoration with skip-connections.
        self.decoder_blocks = nn.ModuleList()

        for level in reversed(range(num_resolutions)):
            out_channels = base_channels * base_channels_multiples[level]

            for _ in range(num_res_blocks + 1):
                encoder_in_channels = curr_channels.pop()
                block = ResnetBlock(
                    in_channels=encoder_in_channels + in_channels,
                    out_channels=out_channels,
                    dropout_rate=dropout_rate,
                    time_emb_dims=time_emb_dims_exp,
                    apply_attention=apply_attention[level],
                )

                in_channels = out_channels
                self.decoder_blocks.append(block)

            if level != 0:
                self.decoder_blocks.append(UpSample(in_channels))

        self.final = nn.Sequential(
            nn.GroupNorm(num_groups=8, num_channels=in_channels),
            nn.SiLU(),
            nn.Conv2d(in_channels=in_channels, out_channels=output_channels, kernel_size=3, stride=1, padding="same"),
        )

    def forward(self, x, t):

        time_emb = self.time_embeddings(t)

        h = self.first(x)
        outs = [h]

        for layer in self.encoder_blocks:
            h = layer(h, time_emb)
            outs.append(h)

        for layer in self.bottleneck_blocks:
            h = layer(h, time_emb)

        for layer in self.decoder_blocks:
            if isinstance(layer, ResnetBlock):
                out = outs.pop()
                h = torch.cat([h, out], dim=1)
            h = layer(h, time_emb)

        h = self.final(h)

        return h

# %% [markdown]
# # Helper functions

# %%
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader:
    """Wrap a dataloader to move data to a device"""

    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl:
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

def get_default_device():
    return torch.device("cuda" if torch.cuda.is_available() else "cpu")

def save_images(images, path, **kwargs):
    grid = make_grid(images, **kwargs)
    ndarr = grid.permute(1, 2, 0).to("cpu").numpy()
    im = Image.fromarray(ndarr)
    im.save(path)

def get(element: torch.Tensor, t: torch.Tensor):
    """
    Get value at index position "t" in "element" and
        reshape it to have the same dimension as a batch of images.
    """
    ele = element.gather(-1, t)
    return ele.reshape(-1, 1, 1, 1)

def setup_log_directory(config):
    '''Log and Model checkpoint directory Setup'''

    if os.path.isdir(config.root_log_dir):
        # Get all folders numbers in the root_log_dir
        folder_numbers = [int(folder.replace("version_", "")) for folder in os.listdir(config.root_log_dir)]

        # Find the latest version number present in the log_dir
        last_version_number = max(folder_numbers)

        # New version name
        version_name = f"version_{last_version_number + 1}"

    else:
        version_name = config.log_dir

    # Update the training config default directory
    log_dir        = os.path.join(config.root_log_dir,        version_name)
    checkpoint_dir = os.path.join(config.root_checkpoint_dir, version_name)

    # Create new directory for saving new experiment version
    os.makedirs(log_dir,        exist_ok=True)
    os.makedirs(checkpoint_dir, exist_ok=True)

    print(f"Logging at: {log_dir}")
    print(f"Model Checkpoint at: {checkpoint_dir}")

    return log_dir, checkpoint_dir

def frames2vid(images, save_path):

    WIDTH = images[0].shape[1]
    HEIGHT = images[0].shape[0]

#     fourcc = cv2.VideoWriter_fourcc(*'XVID')
#     fourcc = 0
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    video = cv2.VideoWriter(save_path, fourcc, 25, (WIDTH, HEIGHT))

    # Appending the images to the video one by one
    for image in images:
        video.write(image)

    # Deallocating memories taken for window creation
    # cv2.destroyAllWindows()
    video.release()
    return

def display_gif(gif_path):
    b64 = base64.b64encode(open(gif_path,'rb').read()).decode('ascii')
    display(HTML(f'<img src="data:image/gif;base64,{b64}" />'))

# %% [markdown]
# # All Configs

# %%
from dataclasses import dataclass

@dataclass
class BaseConfig:
    DEVICE = get_default_device()
    DATASET = "Flowers" #  "MNIST", "Cifar-10", "Cifar-100", "Flowers"

    # For logging inferece images and saving checkpoints.
    root_log_dir = os.path.join("Logs_Checkpoints", "Inference")
    root_checkpoint_dir = os.path.join("Logs_Checkpoints", "checkpoints")

    # Current log and checkpoint directory.
    log_dir = "version_0"
    checkpoint_dir = "version_0"

@dataclass
class TrainingConfig:
    TIMESTEPS = 1000 # Define number of diffusion timesteps
    IMG_SHAPE = (1, 32, 32) if BaseConfig.DATASET == "MNIST" else (3, 192, 192)
    NUM_EPOCHS = 700
    BATCH_SIZE = 2
    LR = 2e-5
    NUM_WORKERS = 2

# %% [markdown]
# # Load Dataset & Build Dataloader

# %%
def get_dataset(dataset_name='MNIST'):
    transforms = TF.Compose(
        [
            TF.ToTensor(),
            TF.Resize((192,192),
                      interpolation=TF.InterpolationMode.BICUBIC,
                      antialias=True),
            TF.RandomHorizontalFlip(),
            TF.Lambda(lambda t: (t * 2) - 1) # Scale between [-1, 1]
        ]
    )

    if dataset_name.upper() == "MNIST":
        dataset = datasets.MNIST(root="data", train=True, download=True, transform=transforms)
    elif dataset_name == "Cifar-10":
        dataset = datasets.CIFAR10(root="data", train=True, download=True, transform=transforms)
    elif dataset_name == "Cifar-100":
        dataset = datasets.CIFAR10(root="data", train=True, download=True, transform=transforms)
    elif dataset_name == "Flowers":
        #dataset = datasets.ImageFolder(root="/kaggle/input/flowers-recognition/flowers", transform=transforms)
        #dataset = datasets.ImageFolder(root="/home/shashank/ShashankCode/Flowers_dataset", transform=transforms)
        dataset = datasets.ImageFolder(root="/content/drive/MyDrive/Colab_notebooks/Image_seprated_class/Img_193", transform=transforms)
    return dataset

def get_dataloader(dataset_name='MNIST',
                   batch_size=32,
                   pin_memory=False,
                   shuffle=True,
                   num_workers=0,
                   device="cpu"
                  ):
    dataset    = get_dataset(dataset_name=dataset_name)
    dataloader = DataLoader(dataset, batch_size=batch_size,
                            pin_memory=pin_memory,
                            num_workers=num_workers,
                            shuffle=shuffle
                           )
    device_dataloader = DeviceDataLoader(dataloader, device)
    return device_dataloader

def inverse_transform(tensors):
    """Convert tensors from [-1., 1.] to [0., 255.]"""
    return ((tensors.clamp(-1, 1) + 1.0) / 2.0) * 255.0

# %% [markdown]
# # Visualize Dataset

# %%
loader = get_dataloader(
    dataset_name=BaseConfig.DATASET,
    batch_size=128,
    device='cpu',
)

# %%
plt.figure(figsize=(12, 6), facecolor='white')

for b_image, _ in loader:
    b_image = inverse_transform(b_image).cpu()
    grid_img = make_grid(b_image / 255.0, nrow=6, padding=True, pad_value=1, normalize=True)
    plt.imshow(grid_img.permute(1, 2, 0))
    plt.axis("off")
    print(b_image.shape)
    break
# Out:
# torch.Size([128, 3, 192, 192])

# %% [markdown]
# # Diffusion Process

# %%
class SimpleDiffusion:
    def __init__(
        self,
        num_diffusion_timesteps=1000,
        img_shape=(3, 64, 64),
        device="cpu",
    ):
        self.num_diffusion_timesteps = num_diffusion_timesteps
        self.img_shape = img_shape
        self.device = device

        self.initialize()

    def initialize(self):
        # BETAs & ALPHAs required at different places in the Algorithm.
        self.beta  = self.get_betas()
        self.alpha = 1 - self.beta

        self_sqrt_beta                       = torch.sqrt(self.beta)
        self.alpha_cumulative                = torch.cumprod(self.alpha, dim=0)
        self.sqrt_alpha_cumulative           = torch.sqrt(self.alpha_cumulative)
        self.one_by_sqrt_alpha               = 1. / torch.sqrt(self.alpha)
        self.sqrt_one_minus_alpha_cumulative = torch.sqrt(1 - self.alpha_cumulative)

    def get_betas(self):
        """linear schedule, proposed in original ddpm paper"""
        scale = 1000 / self.num_diffusion_timesteps
        beta_start = scale * 1e-4
        beta_end = scale * 0.02
        return torch.linspace(
            beta_start,
            beta_end,
            self.num_diffusion_timesteps,
            dtype=torch.float32,
            device=self.device,
        )

def forward_diffusion(sd: SimpleDiffusion, x0: torch.Tensor, timesteps: torch.Tensor):
    eps = torch.randn_like(x0)  # Noise
    mean    = get(sd.sqrt_alpha_cumulative, t=timesteps) * x0  # Image scaled
    std_dev = get(sd.sqrt_one_minus_alpha_cumulative, t=timesteps) # Noise scaled
    sample  = mean + std_dev * eps # scaled inputs * scaled noise

    return sample, eps  # return ... , gt noise --> model predicts this)

# %% [markdown]
# # Sample Forward Diffusion Process

# %%
sd = SimpleDiffusion(num_diffusion_timesteps=TrainingConfig.TIMESTEPS, device="cpu")

loader = iter(  # converting dataloader into an iterator for now.
    get_dataloader(
        dataset_name=BaseConfig.DATASET,
        batch_size=6,
        device="cpu",
    )
)

# %%
x0s, _ = next(loader)

noisy_images = []
specific_timesteps = [0, 10, 50, 100, 150, 200, 250, 300, 400, 600, 800, 999]

for timestep in specific_timesteps:
    timestep = torch.as_tensor(timestep, dtype=torch.long)

    xts, _ = forward_diffusion(sd, x0s, timestep)
    xts = inverse_transform(xts) / 255.0
    xts = make_grid(xts, nrow=1, padding=1)

    noisy_images.append(xts)

# Plot and see samples at different timesteps

_, ax = plt.subplots(1, len(noisy_images), figsize=(20, 10), facecolor="white")

for i, (timestep, noisy_sample) in enumerate(zip(specific_timesteps, noisy_images)):
    ax[i].imshow(noisy_sample.squeeze(0).permute(1, 2, 0))
    ax[i].set_title(f"t={timestep}", fontsize=8)
    ax[i].axis("off")
    ax[i].grid(False)

plt.suptitle("Forward Diffusion Process", y=0.9)
plt.axis("off")
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Training

# %%
@dataclass
class ModelConfig:
    BASE_CH = 64  # 64, 128, 256, 256
    BASE_CH_MULT = (1, 2, 4, 4) # 32, 16, 8, 8
    APPLY_ATTENTION = (False, True, True, False)
    DROPOUT_RATE = 0.1
    TIME_EMB_MULT = 4 # 128

# %%
model = UNet(
    input_channels          = TrainingConfig.IMG_SHAPE[0],
    output_channels         = TrainingConfig.IMG_SHAPE[0],
    base_channels           = ModelConfig.BASE_CH,
    base_channels_multiples = ModelConfig.BASE_CH_MULT,
    apply_attention         = ModelConfig.APPLY_ATTENTION,
    dropout_rate            = ModelConfig.DROPOUT_RATE,
    time_multiple           = ModelConfig.TIME_EMB_MULT,
)
#checkpoint_dir = '/content/Logs_Checkpoints/checkpoints/version_2'
#model.load_state_dict(torch.load(os.path.join(checkpoint_dir, "ckpt.tar"), map_location='cpu')['model'])
model.to(BaseConfig.DEVICE)

optimizer = torch.optim.AdamW(model.parameters(), lr=TrainingConfig.LR)

dataloader = get_dataloader(
    dataset_name  = BaseConfig.DATASET,
    batch_size    = TrainingConfig.BATCH_SIZE,
    device        = BaseConfig.DEVICE,
    pin_memory    = True,
    num_workers   = TrainingConfig.NUM_WORKERS,
)

loss_fn = nn.MSELoss()

sd = SimpleDiffusion(
    num_diffusion_timesteps = TrainingConfig.TIMESTEPS,
    img_shape               = TrainingConfig.IMG_SHAPE,
    device                  = BaseConfig.DEVICE,
)

scaler = amp.GradScaler()

# %%
total_epochs = TrainingConfig.NUM_EPOCHS + 1
log_dir, checkpoint_dir = setup_log_directory(config=BaseConfig())

generate_video = False
ext = ".mp4" if generate_video else ".png"
# Out:
# Logging at: Logs_Checkpoints/Inference/version_0
# Model Checkpoint at: Logs_Checkpoints/checkpoints/version_0

# %%
# Algorithm 1: Training

def train_one_epoch(model, sd, loader, optimizer, scaler, loss_fn, epoch=800,
                   base_config=BaseConfig(), training_config=TrainingConfig()):

    loss_record = MeanMetric()
    model.train()

    with tqdm(total=len(loader), dynamic_ncols=True) as tq:
        tq.set_description(f"Train :: Epoch: {epoch}/{training_config.NUM_EPOCHS}")

        for x0s, _ in loader:
            tq.update(1)

            ts = torch.randint(low=1, high=training_config.TIMESTEPS, size=(x0s.shape[0],), device=base_config.DEVICE)
            xts, gt_noise = forward_diffusion(sd, x0s, ts)

            with amp.autocast(dtype=torch.float16):
                pred_noise = model(xts, ts)
                loss = loss_fn(gt_noise, pred_noise)

            optimizer.zero_grad(set_to_none=True)
            scaler.scale(loss).backward()

            # scaler.unscale_(optimizer)
            # torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

            scaler.step(optimizer)
            scaler.update()

            loss_value = loss.detach().item()
            loss_record.update(loss_value)

            tq.set_postfix_str(s=f"Loss: {loss_value:.4f}")

        mean_loss = loss_record.compute().item()

        tq.set_postfix_str(s=f"Epoch Loss: {mean_loss:.4f}")

    # for name, param in model.named_parameters():
    #     print(f'{name}: {param.dtype}')

    return mean_loss

# %%
# Algorithm 2: Sampling - save each image

@torch.no_grad()
def reverse_diffusion(model, sd, timesteps=1000, img_shape=(3, 64, 64),
                      num_images=5, nrow=8, device="cpu",save_indv_folder=False, **kwargs):

    x = torch.randn((num_images, *img_shape), device=device)
    model.eval()

    if kwargs.get("generate_video", False):
        outs = []

    for time_step in tqdm(iterable=reversed(range(1, timesteps)),
                          total=timesteps-1, dynamic_ncols=False,
                          desc="Sampling :: ", position=0):

        ts = torch.ones(num_images, dtype=torch.long, device=device) * time_step
        z = torch.randn_like(x) if time_step > 1 else torch.zeros_like(x)

        predicted_noise = model(x, ts)

        beta_t                            = get(sd.beta, ts)
        one_by_sqrt_alpha_t               = get(sd.one_by_sqrt_alpha, ts)
        sqrt_one_minus_alpha_cumulative_t = get(sd.sqrt_one_minus_alpha_cumulative, ts)

        x = (
            one_by_sqrt_alpha_t
            * (x - (beta_t / sqrt_one_minus_alpha_cumulative_t) * predicted_noise)
            + torch.sqrt(beta_t) * z
        )

        if kwargs.get("generate_video", False):
            x_inv = inverse_transform(x).type(torch.uint8)
            grid = make_grid(x_inv, nrow=nrow, pad_value=255.0).to("cpu")
            ndarr = torch.permute(grid, (1, 2, 0)).numpy()[:, :, ::-1]
            outs.append(ndarr)

    if kwargs.get("generate_video", False): # Generate and save video of the entire reverse process.
        frames2vid(outs, kwargs['save_path'])
        display(Image.fromarray(outs[-1][:, :, ::-1])) # Display the image at the final timestep of the reverse process.
        return None

    else: # Display and save the image at the final timestep of the reverse process.
        x = inverse_transform(x).type(torch.uint8)

        # Create a folder for individual images if it doesn't exist
        # Initializing timestamp to save folder according to time
        timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
        if (save_indv_folder == True):

            individual_images_folder = f'generated_images_193/individual_images_{timestamp}'
            os.makedirs(individual_images_folder, exist_ok=True)
        else:

            individual_images_folder = f'individual_images_training_193/individual_images_{timestamp}'
            os.makedirs(individual_images_folder, exist_ok=True)

        for i in range(x.shape[0]):
            # Save each individual image
            individual_image_path = os.path.join(individual_images_folder, f'image_{i+1}.png')
            #individual_image = inverse_transform(x[i]).type(torch.uint8)
            TF.functional.to_pil_image(x[i]).save(individual_image_path)


        grid = make_grid(x, nrow=nrow, pad_value=255.0).to("cpu")
        pil_image = TF.functional.to_pil_image(grid)
        pil_image.save(kwargs['save_path'], format=save_path[-3:].upper())
        display(pil_image)
        return None

# %%
for epoch in range(1, total_epochs):
    torch.cuda.empty_cache()
    gc.collect()

    # Algorithm 1: Training
    loss = train_one_epoch(model, sd, dataloader, optimizer, scaler, loss_fn, epoch=epoch)

    if epoch % 25 == 0:
        save_path = os.path.join(log_dir, f"{epoch}{ext}")
        torch.cuda.empty_cache()
        gc.collect()
        # Profiling memory usage
        current_memory = memory_allocated()
        max_memory = torch.cuda.max_memory_allocated()
        cached_memory = memory_cached()

        # Algorithm 2: Sampling
        reverse_diffusion(model, sd, timesteps=TrainingConfig.TIMESTEPS, num_images=8, generate_video=generate_video,
            save_path=save_path, img_shape=TrainingConfig.IMG_SHAPE, device=BaseConfig.DEVICE,
        )
        # print(f"Epoch {epoch + 1}:")
        # print(f"Current memory allocated: {current_memory / 1024 / 1024:.2f} MB")
        # print(f"Max memory allocated: {max_memory / 1024 / 1024:.2f} MB")
        # print(f"Cached memory: {cached_memory / 1024 / 1024:.2f} MB")

        # clear_output()
        checkpoint_dict = {
            "opt": optimizer.state_dict(),
            "scaler": scaler.state_dict(),
            "model": model.state_dict()
        }
        torch.save(checkpoint_dict, os.path.join(checkpoint_dir, "ckpt.tar"))
        del checkpoint_dict
        # Reset max memory allocated for the next epoch
        reset_max_memory_allocated()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# 2137

# %% [markdown]
# # Inference

# %%
model = UNet(
    input_channels          = TrainingConfig.IMG_SHAPE[0],
    output_channels         = TrainingConfig.IMG_SHAPE[0],
    base_channels           = ModelConfig.BASE_CH,
    base_channels_multiples = ModelConfig.BASE_CH_MULT,
    apply_attention         = ModelConfig.APPLY_ATTENTION,
    dropout_rate            = ModelConfig.DROPOUT_RATE,
    time_multiple           = ModelConfig.TIME_EMB_MULT,
)
checkpoint_dir = '/content/drive/MyDrive/Colab_notebooks/'
model.load_state_dict(torch.load(os.path.join(checkpoint_dir, "ckpt_193.tar"), map_location='cpu')['model'])
#model.load_state_dict(torch.load(os.path.join(checkpoint_dir, "ckpt.tar"), map_location='cpu')['model'])

model.to(BaseConfig.DEVICE)

sd = SimpleDiffusion(
    num_diffusion_timesteps = TrainingConfig.TIMESTEPS,
    img_shape               = TrainingConfig.IMG_SHAPE,
    device                  = BaseConfig.DEVICE,
)

log_dir = "inference_results"
os.makedirs(log_dir, exist_ok=True)

# %%
# generate_video = True

# ext = ".mp4" if generate_video else ".png"
# filename = f"{datetime.now().strftime('%Y%m%d-%H%M%S')}{ext}"

# save_path = os.path.join(log_dir, filename)

# reverse_diffusion(
#     model,
#     sd,
#     num_images=16,
#     generate_video=generate_video,
#     save_path=save_path,
#     timesteps=1000,
#     img_shape=TrainingConfig.IMG_SHAPE,
#     device=BaseConfig.DEVICE,
#     nrow=32,
# )
# print(save_path)

# %%
for i in range(25):
    generate_video = False
    print("epoch_no: ",i)
    ext = ".mp4" if generate_video else ".png"
    filename = f"{datetime.now().strftime('%Y%m%d-%H%M%S')}{ext}"

    save_path = os.path.join(log_dir, filename)


    reverse_diffusion(
        model,
        sd,
        num_images=16,
        generate_video=generate_video,
        save_path=save_path,
        timesteps=1000,
        img_shape=TrainingConfig.IMG_SHAPE,
        device=BaseConfig.DEVICE,
        nrow=8,
        save_indv_folder = True

    )

    print(save_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
for i in range(5):
    generate_video = False

    ext = ".mp4" if generate_video else ".png"
    filename = f"{datetime.now().strftime('%Y%m%d-%H%M%S')}{ext}"

    save_path = os.path.join(log_dir, filename)


    reverse_diffusion(
        model,
        sd,
        num_images=16,
        generate_video=generate_video,
        save_path=save_path,
        timesteps=1000,
        img_shape=TrainingConfig.IMG_SHAPE,
        device=BaseConfig.DEVICE,
        nrow=8,
        save_indv_folder = True,

    print(save_path)

# %%
generate_video = False

ext = ".mp4" if generate_video else ".png"
filename = f"{datetime.now().strftime('%Y%m%d-%H%M%S')}{ext}"

save_path = os.path.join(log_dir, filename)


reverse_diffusion(
    model,
    sd,
    num_images=16,
    generate_video=generate_video,
    save_path=save_path,
    timesteps=1000,
    img_shape=TrainingConfig.IMG_SHAPE,
    device=BaseConfig.DEVICE,
    nrow=8,
)
print(save_path)

# %%
# !zip -r /content/individual_images_training_295 /content/individual_images_training_295
# Out:
# updating: content/individual_images_training_295/ (stored 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/ (stored 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_5.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_1.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_7.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_6.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_3.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_4.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_2.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-15-38/image_8.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/ (stored 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_5.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_1.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_7.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_6.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_3.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_4.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_2.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_06-54-06/image_8.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/ (stored 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_5.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_1.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_7.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_6.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_3.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_4.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_2.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-41-47/image_8.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/ (stored 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_5.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_1.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_7.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_6.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_3.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_4.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_2.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-37-10/image_8.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/ (stored 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_5.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_1.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_7.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_6.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_3.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_4.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_2.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_08-20-14/image_8.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/ (stored 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_5.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_1.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_7.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_6.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_3.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_4.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_2.png (deflated 0%)
# updating: content/individual_images_training_295/individual_images_2024-03-14_07-58-41/image_8.png (deflated 0%)

# %%
# !zip -r /content/Logs_Checkpoints/checkpoints/version_2 /content/Logs_Checkpoints/checkpoints/version_2
# Out:
#   adding: content/Logs_Checkpoints/checkpoints/version_2/ (stored 0%)
#   adding: content/Logs_Checkpoints/checkpoints/version_2/ckpt.tar (deflated 9%)

# %%
# !zip -r /content/generated_images_193 /content/generated_images_193
# Out:
#   adding: content/generated_images_193/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-12-50/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-28-54/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-13-08/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-19-19/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-06-39/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-57-04/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-16-13/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-35-06/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-25-31/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-47-46/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-57-22/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-50-52/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_07-44-41/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-00-27/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-09-44/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-05-48/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-25-49/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_09-03-33/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-22-25/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_08-32-00/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-38-11/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-28-37/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_10-53-58/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_06-41-35/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_11-41-17/image_12.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/ (stored 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_3.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_16.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_14.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_7.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_9.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_10.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_11.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_2.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_8.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_4.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_15.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_13.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_1.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_5.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_6.png (deflated 0%)
#   adding: content/generated_images_193/individual_images_2024-03-18_12-44-23/image_12.png (deflated 0%)

# %%
# !cp generated_images_193.zip '/content/drive/MyDrive/Colab_notebooks'

# %%
# !cp individual_images_training_295.zip '/content/drive/MyDrive/Colab_notebooks'

# %%
# !cp /content/Logs_Checkpoints/checkpoints/version_2.zip '/content/drive/MyDrive/Colab_notebooks'

# %%
# !ls -lt '/content/drive/MyDrive/Colab_notebooks'
# Out:
# total 890876
# -rw------- 1 root root 280876632 Mar  8 07:23  version_0.zip
# -rw------- 1 root root    241134 Mar  8 07:22  DDPM_APTOS_ocv.ipynb
# -rw------- 1 root root   4370373 Mar  8 07:22  individual_images_training_999.zip
# -rw------- 1 root root 308229178 Mar  8 01:45  ckpt_999.tar
# -rw------- 1 root root   2173630 Mar  6 18:06  generated_images_999.zip
# drwx------ 2 root root      4096 Mar  5 08:33  individual_images_training_193
# -rw------- 1 root root   6657423 Mar  4 07:30  generated_images_370.zip
# drwx------ 2 root root      4096 Mar  4 05:45  DDPM_Weights
# drwx------ 6 root root      4096 Feb 26 09:45  Image_seprated_class
# -rw------- 1 root root 308229178 Feb 25 10:46 'Copy of ckpt.tar'
# -rw------- 1 root root   1397773 Jan 17 23:39 'DDPM_APTOS_ocv (1).ipynb'
# -rw------- 1 root root     50635 Jan 17 09:59  lucidrain_DDPM
# drwx------ 2 root root      4096 Oct 24 09:55  APTOS_dataset
# drwx------ 2 root root      4096 Oct 20 06:52  flowers
# drwx------ 2 root root      4096 Sep 24 10:41  denoising-diffusion-flax-main
# drwx------ 2 root root      4096 Aug 16  2023  CampusX
